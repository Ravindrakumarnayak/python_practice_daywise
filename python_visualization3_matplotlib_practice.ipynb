# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindrakumarnayak/python_practice_daywise/blob/main/python_visualization3_matplotlib_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as plt
import seaborn as sns

# %%
df=sns.load_dataset("exercise")
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.barplot(x="id",y="diet",data=df)
# Out:
# <Axes: xlabel='id', ylabel='diet'>

# %%
sns.countplot(x="id",data=df)
# Out:
# <Axes: xlabel='id', ylabel='count'>

# %%
sns.countplot(x="kind",data=df)
# Out:
# <Axes: xlabel='kind', ylabel='count'>

# %%
sns.countplot(x="diet",data=df)
# Out:
# <Axes: xlabel='diet', ylabel='count'>

# %%
sns.stripplot(x="id",y="diet",data=df)
# Out:
# <Axes: xlabel='id', ylabel='diet'>

# %%
sns.stripplot(x="id",y="pulse",data=df)
# Out:
# <Axes: xlabel='id', ylabel='pulse'>

# %%
sns.swarmplot(x="id",y="pulse",data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='id', ylabel='pulse'>

# %%
sns.swarmplot(x="id",y="time",data=df)
# Out:
# <Axes: xlabel='id', ylabel='time'>

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x="species", y="sepal_length",data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.histplot(x="petal_length",data=df)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.displot(x="petal_length",data=df)

# %%
sns.displot(x="sepal_length",data=df)

# %%
df.corr()
sns.heatmap(data=df.corr()) # 1 is highly correlated
# Out:
# <ipython-input-21-0043cfd919c7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# <ipython-input-21-0043cfd919c7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr())
# <Axes: >

# %%
df=sns.load_dataset("diamonds")

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.corr()
# Out:
# <ipython-input-27-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
sns.heatmap(data=df.corr()) # to understand preprocessing , we create heatmap with numbers, highly corelated map we try to drop because high similarity
# Out:
# <ipython-input-29-afb2b4e09bbc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr())
# <Axes: >

# %%
sns.heatmap(data=df.corr(),cmap="tab20")
# Out:
# <ipython-input-30-746eb80f4ec1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),cmap="tab20")
# <Axes: >

# %%
sns.heatmap(data=df.corr(),cmap="tab20", center=0)
# Out:
# <ipython-input-31-b0a5cde46c32>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),cmap="tab20", center=0)
# <Axes: >

# %%
sns.heatmap(data=df.corr(),cmap="tab20", center=0, annot=True) # annot is used to display numbers in heatmap
# Out:
# <ipython-input-32-ab4d72b7d020>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),cmap="tab20", center=0, annot=True)
# <Axes: >

# %%
sns.heatmap(data=df.corr(),cmap="tab20", center=0, annot=True, linewidths=3,linecolor="Yellow") # cmap is argument
# Out:
# <ipython-input-33-0b68f29a7fcd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),cmap="tab20", center=0, annot=True, linewidths=3,linecolor="Yellow")
# <Axes: >

# %%
df=sns.load_dataset("mpg")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.jointplot(x="mpg",y="acceleration", hue="model_year", data=df)

# %%
sns.jointplot(x="mpg",y="acceleration",kind="hex",data=df)

# %%
sns.jointplot(x="mpg",y="acceleration",kind="kde",data=df)

# %%
sns.jointplot(x="mpg",y="acceleration",kind="scatter",data=df)
