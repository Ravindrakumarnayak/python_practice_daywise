# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindrakumarnayak/python_practice_daywise/blob/main/web_scrapping_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# we have pip install in anaconda prompt all these pandas,requests and beautiful soup

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com"

# %%
r=requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
url1="https://www.flipkart.com/search?q=mobile%20under%205000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
s=requests.get(url1)
s
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(s.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
np=soup.find("a",class_="_1LKT03").get("href")
np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-4853572e5f4a> in <cell line: 1>()
# ----> 1 np=soup.find("a",class_="_1LKT03").get("href")
#       2 np
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
cnp="https://www.flipkart.com"+np
cnp

# %%
for i in range(2,10):
  url1="https://www.flipkart.com/nokia-6310/p/itm8c929ad054024?pid=MOBG6VXH58HKECXJ&lid=LSTMOBG6VXH58HKECXJNIAE5G&marketplace=FLIPKART&q=mobile+under+5000&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=380df152-6986-4080-9d9b-882b26148fb1.MOBG6VXH58HKECXJ.SEARCH&ppt=None&ppn=None&ssid=2mgjwm3xhc0000001692197957952&qH=66aec696f09cbf01"+str(i)
  s=requests.get(url1)
  soup=BeautifulSoup(s.text,"lxml")
  np=soup.find("a",class_="_1LKT03").get("href")
  cnp="https://www.flipkart.com"+np
  print(cnp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-619c605cbdcc> in <cell line: 1>()
#       3   s=requests.get(url1)
#       4   soup=BeautifulSoup(s.text,"lxml")
# ----> 5   np=soup.find("a",class_="_1LKT03").get("href")
#       6   cnp="https://www.flipkart.com"+np
#       7   print(cnp)
#
# AttributeError: 'NoneType' object has no attribute 'get'
