# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindrakumarnayak/python_practice_daywise/blob/main/python_practice_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints= np.array([0,6])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints, linestyle='dotted')
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints, linestyle='dotted')
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints, linestyle='dashed')
plt.xlabel("average")
plt.ylabel("calorie")
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints, linestyle='dashed')
plt.xlabel("average")
plt.ylabel("calorie")
plt.title("graph")
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints, linestyle='dashed')
font1={"family":"serif",'color':"blue", 'size':15}
font2={"family":"serif",'color':"darkred", 'size':25}
plt.xlabel("average",fontdict=font1)
plt.ylabel("calorie",fontdict=font2)
plt.title("colorie-average graph",fontdict=font1)
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints, linestyle='dashed')

font1={
    "family":"serif",
    'color':"orange",
    'size':15
    }

font2={
    "family":"serif",
    'color':"green",
    'size':25
    }

plt.xlabel("average",fontdict=font1)
plt.ylabel("calorie",fontdict=font2)
plt.title("colorie-average graph",fontdict=font1)
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints, linestyle='dashed')

font1={
    "family":"serif",
    'color':"orange",
    'size':15
    }

font2={
    "family":"serif",
    'color':"green",
    'size':25
    }

plt.xlabel("average",fontdict=font1)
plt.ylabel("calorie",fontdict=font2)
plt.title("colorie-average graph",fontdict=font1)
plt.grid()
plt.show()

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.plot(xpoints,ypoints, linestyle='dashed')

font1={
    "family":"serif",
    'color':"orange",
    'size':15
    }

font2={
    "family":"serif",
    'color':"green",
    'size':25
    }

plt.xlabel("average",fontdict=font1)
plt.ylabel("calorie",fontdict=font2)
plt.title("colorie-average graph",fontdict=font1)
plt.grid(axis='y')

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])
plt.scatter(xpoints,ypoints, linestyle='dashed')

font1={
    "family":"serif",
    'color':"orange",
    'size':15
    }

font2={
    "family":"serif",
    'color':"green",
    'size':25
    }

plt.xlabel("average",fontdict=font1)
plt.ylabel("calorie",fontdict=font2)
plt.title("colorie-average graph",fontdict=font1)
plt.grid(axis='y')

# %%
xpoints= np.array([0,6,54,78,32])
ypoints=np.array([0,250,456,785,34])

plt.scatter(xpoints,ypoints)
xpoints= np.array([2,6,541,782,32])
ypoints=np.array([0,2510,4536,7825,334])

plt.scatter(xpoints,ypoints)

# %%
xpoints=np.array(["a","b","c","d"])
ypoints=np.array([12,34,22,44])
plt.barh(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array(["a","b","c","d"])
ypoints=np.array([12,34,22,44])
plt.bar(xpoints,ypoints,color="orange")
plt.show()

# %%
xpoints=np.array(["a","b","c","d"])
ypoints=np.array([12,34,22,44])
plt.bar(xpoints,ypoints,color="orange",width=0.1) # for vertical width works
plt.show()

# %%
xpoints=np.array(["a","b","c","d"])
ypoints=np.array([12,34,22,44])
plt.barh(xpoints,ypoints,color="orange",height=0.1)   # horizontal height works
plt.show()

# %%
x=np.random.normal(170,10,250)
x
# Out:
# array([183.78483771, 178.83273636, 158.27118064, 176.37734538,
#        161.39790431, 169.11636797, 174.0208898 , 177.7748687 ,
#        165.02609964, 158.63887469, 185.92959009, 183.05146828,
#        153.52761885, 145.1695927 , 150.33697888, 163.68104121,
#        171.6480218 , 172.56530259, 187.32826763, 183.71229344,
#        162.01682776, 167.99101338, 179.91368861, 170.96025682,
#        182.90014136, 189.14877253, 171.33074407, 178.56088091,
#        186.42230519, 163.96362472, 172.97815446, 169.61334476,
#        168.51521894, 175.19145015, 160.553468  , 170.9855529 ,
#        167.74926058, 165.65075997, 172.35141997, 174.53419225,
#        165.94275605, 167.88088164, 167.99348164, 165.48714307,
#        170.14104254, 172.7331137 , 177.08524862, 157.51749913,
#        170.02280473, 166.54477756, 167.50740762, 164.68340426,
#        178.8468678 , 176.50022618, 171.25270615, 175.47726906,
#        189.87258251, 159.42386329, 168.13299843, 169.34120299,
# ...

# %%
plt.hist(x)
# Out:
# (array([ 2.,  6., 11., 18., 40., 59., 51., 36., 18.,  9.]),
#  array([139.06796559, 144.36217865, 149.6563917 , 154.95060476,
#         160.24481781, 165.53903087, 170.83324392, 176.12745698,
#         181.42167003, 186.71588309, 192.01009614]),
#  <BarContainer object of 10 artists>)

# %%
x.shape
# Out:
# (250,)

# %%
import pandas as pd

x=pd.DataFrame(x)

# %%
x.describe()
# Out:
#                 0
# count  250.000000
# mean   169.526701
# std      9.680210
# min    139.067966
# 25%    164.076954
# 50%    169.587888
# 75%    176.031839
# max    192.010096

# %%
x=np.array([10,45,10,35])
mylabels= ["apple","banana","cherry","cake"]
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x796057789bd0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(-0.4993895221842244, 0.9801071906340715, ''),
#   Text(-0.889918733160626, -0.6465637233635884, ''),
#   Text(0.4993894763020944, -0.9801072140121815, '')])

# %%
x=np.array([10,45,10,35])
mylabels= ["apple","banana","cherry","cake"]
plt.pie(x,labels=mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x796053ff7280>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'apple'),
#   Text(-0.4993895221842244, 0.9801071906340715, 'banana'),
#   Text(-0.889918733160626, -0.6465637233635884, 'cherry'),
#   Text(0.4993894763020944, -0.9801072140121815, 'cake')])

# %%
x=np.array([10,45,10,35])
mylabels= ["apple","banana","cherry","cake"]
fig,ax=plt.subplots()
plt.pie(x, labels=mylabels, autopct='%1.1f%%') # autopct for float values percent values
# Out:
# ([<matplotlib.patches.Wedge at 0x796053df90f0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'apple'),
#   Text(-0.4993895221842244, 0.9801071906340715, 'banana'),
#   Text(-0.889918733160626, -0.6465637233635884, 'cherry'),
#   Text(0.4993894763020944, -0.9801072140121815, 'cake')],
#  [Text(0.5706339089091244, 0.1854101992962986, '10.0%'),
#   Text(-0.27239428482775874, 0.534603922164039, '45.0%'),
#   Text(-0.4854102180876141, -0.3526711218346845, '10.0%'),
#   Text(0.27239425980114235, -0.5346039349157353, '35.0%')])

# %%
x=np.array([10,45,10,35])
mylabels= ["apple","banana","cherry","cake"]
#fig,ax=plt.subplots()
plt.pie(x, labels=mylabels, autopct='%1.1f%%') # autopct for float values percent values
plt.show()

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
